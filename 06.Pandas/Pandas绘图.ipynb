# %% [markdown]
# ## DataFrame绘图

# %% [markdown]
# ### 绘制折线图

# %%
import pandas as pd
import numpy as np
data = np.random.randn(10, 2)  # 从标准动态分布中返回一个或多个样本值
print(data)
df = pd.DataFrame(data=data)
print(df)
df.plot(kind='line')  # df.plot.line()，df.plot()函数的参数kind默认是'line'
# Out:
# [[ 2.09603573 -1.04536752]
#  [-1.04862055 -0.79370932]
#  [-1.12497991 -0.32224515]
#  [-0.53921947 -1.03912416]
#  [-0.8888893  -0.81321562]
#  [ 0.71288176  0.53287184]
#  [ 0.99234172  2.67071385]
#  [ 0.99220206  0.57149816]
#  [ 0.72147469 -0.12993599]
#  [ 0.30782828  0.63459508]]
#           0         1
# 0  2.096036 -1.045368
# 1 -1.048621 -0.793709
# 2 -1.124980 -0.322245
# 3 -0.539219 -1.039124
# 4 -0.888889 -0.813216
# 5  0.712882  0.532872
# 6  0.992342  2.670714
# 7  0.992202  0.571498
# 8  0.721475 -0.129936
# 9  0.307828  0.634595

# %% [markdown]
# ### 绘制柱状图

# %%
import pandas as pd
import numpy as np
data = np.random.randn(10, 3)  # 从标准动态分布中返回一个或多个样本值
print(data)
df = pd.DataFrame(data=data)
print(df)
df.plot(kind='bar')  # df.plot()函数的参数kind默认是'line'
# Out:
# [[ 0.8253559   0.70415396  0.55724268]
#  [-0.81542262 -1.43788394 -1.97062772]
#  [ 1.09820491 -1.02237649  0.90985692]
#  [ 1.36737415  0.33161116  1.68718853]
#  [ 0.01239575 -0.05782502  0.36731734]
#  [-1.55580868 -1.60372783  0.70796986]
#  [-0.79536026 -0.27102491 -0.67928867]
#  [ 0.00787258 -1.32356513  1.02015411]
#  [ 0.80558346  1.02987021 -0.55207555]
#  [ 0.60901915  0.92446427  0.78398305]]
#           0         1         2
# 0  0.825356  0.704154  0.557243
# 1 -0.815423 -1.437884 -1.970628
# 2  1.098205 -1.022376  0.909857
# 3  1.367374  0.331611  1.687189
# 4  0.012396 -0.057825  0.367317
# 5 -1.555809 -1.603728  0.707970
# 6 -0.795360 -0.271025 -0.679289
# 7  0.007873 -1.323565  1.020154
# 8  0.805583  1.029870 -0.552076
# 9  0.609019  0.924464  0.783983

# %%
import pandas as pd
import numpy as np
data = np.random.randn(10, 3)  # 从标准动态分布中返回一个或多个样本值
df = pd.DataFrame(data=data)
df.plot(kind='barh')  # df.plot()函数的参数kind默认是'line'

# %% [markdown]
# ### 绘制直方图

# %%
import pandas as pd
import numpy as np
data = np.random.randn(10, 3)  # 从标准动态分布中返回一个或多个样本值
print(data)
df = pd.DataFrame(data=data)
print(df)
df.plot(kind='hist')  # df.plot()函数的参数kind默认是'line'
# Out:
# [[-1.20680471  1.36326476  1.40471802]
#  [-0.16132107 -0.00392282  1.78412717]
#  [ 0.87014799  0.47245997 -1.04472073]
#  [-0.381194    0.19546574  2.20863955]
#  [ 0.80747998  0.86125389 -1.4435027 ]
#  [ 1.17215347  0.48183524 -1.12059471]
#  [-1.42437378 -1.37449832  0.88542357]
#  [-0.28570339  1.18327412 -2.02605862]
#  [-1.54689267  1.25631746 -0.14388516]
#  [ 1.52088466 -1.17737662  1.93333083]]
#           0         1         2
# 0 -1.206805  1.363265  1.404718
# 1 -0.161321 -0.003923  1.784127
# 2  0.870148  0.472460 -1.044721
# 3 -0.381194  0.195466  2.208640
# 4  0.807480  0.861254 -1.443503
# 5  1.172153  0.481835 -1.120595
# 6 -1.424374 -1.374498  0.885424
# 7 -0.285703  1.183274 -2.026059
# 8 -1.546893  1.256317 -0.143885
# 9  1.520885 -1.177377  1.933331

# %% [markdown]
# ## Series绘图

# %% [markdown]
# ### 绘制折线图

# %%
import pandas as pd
import numpy as np
import random
data = []
for i in np.arange(10):
    data.append(random.randint(0, 20))
s = pd.Series(data=data)
print(s)
s.plot(kind='line')  # s.plot.line()，s.plot()函数的参数kind默认是'line'
# Out:
# 0     5
# 1    17
# 2    14
# 3     1
# 4    15
# 5     3
# 6     8
# 7     0
# 8    19
# 9    17
# dtype: int64

# %% [markdown]
# ### 绘制柱状图

# %%
import pandas as pd
import numpy as np
import random
data = []
for i in np.arange(0, 100, 10):
    data.append(random.randint(10, 20))
s = pd.Series(data=data)
print(s)
s.plot(kind='bar')
# Out:
# 0    19
# 1    12
# 2    17
# 3    14
# 4    19
# 5    15
# 6    18
# 7    18
# 8    11
# 9    10
# dtype: int64

# %%
import pandas as pd
import numpy as np
import random
data = []
for i in np.arange(0, 100, 10):
    data.append(random.randint(10, 20))
s = pd.Series(data=data)
print(s)
s.plot(kind='barh')
# Out:
# 0    18
# 1    20
# 2    13
# 3    14
# 4    18
# 5    15
# 6    19
# 7    15
# 8    13
# 9    13
# dtype: int64

# %% [markdown]
# ### 绘制直方图

# %%
import pandas as pd
import numpy as np
import random
data = []
for i in np.arange(0, 100, 10):
    data.append(random.randint(10, 20))
data = np.random.normal(1.75, 1, 10000) 
s = pd.Series(data=data)
print(s)
s.plot(kind='hist')
# Out:
# 0       2.365378
# 1       2.822626
# 2       2.083046
# 3       3.660244
# 4       1.231272
#           ...
# 9995    0.269740
# 9996    1.897995
# 9997    1.169698
# 9998    2.485033
# 9999    0.684052
# Length: 10000, dtype: float64
